# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lead = pd.read_csv('Leads.csv' , encoding = 'ISO-8859-1')
lead.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit          ...           \
# ...

# %%
lead.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
# Prospect ID                                      9240 non-null object
# Lead Number                                      9240 non-null int64
# Lead Origin                                      9240 non-null object
# Lead Source                                      9204 non-null object
# Do Not Email                                     9240 non-null object
# Do Not Call                                      9240 non-null object
# Converted                                        9240 non-null int64
# TotalVisits                                      9103 non-null float64
# Total Time Spent on Website                      9240 non-null int64
# Page Views Per Visit                             9103 non-null float64
# Last Activity                                    9137 non-null object
# Country                                          6779 non-null object
# ...

# %%
lead.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
lead.var() , len(lead.index)
# Out:
# (Lead Number                    5.478406e+08
#  Converted                      2.368901e-01
#  TotalVisits                    2.356959e+01
#  Total Time Spent on Website    3.003275e+05
#  Page Views Per Visit           4.671727e+00
#  Asymmetrique Activity Score    1.922920e+00
#  Asymmetrique Profile Score     3.281152e+00
#  dtype: float64, 9240)

# %%
lead.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
lead.isnull().sum(axis = 1)
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
# 5       9
# 6       0
# 7       9
# 8       6
# 9       5
# 10      0
# 11      1
# 12      0
# 13      1
# 14      2
# 15      0
# 16      9
# 17      0
# 18      2
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      0
# 25      0
# 26      0
# 27      0
# 28      1
# 29      0
#        ..
# 9210    0
# 9211    0
# 9212    0
# 9213    6
# 9214    8
# 9215    6
# 9216    0
# 9217    1
# 9218    5
# 9219    0
# 9220    1
# 9221    4
# 9222    0
# 9223    0
# 9224    1
# 9225    0
# 9226    1
# 9227    0
# 9228    4
# 9229    0
# 9230    1
# 9231    0
# 9232    0
# 9233    5
# 9234    0
# 9235    0
# 9236    0
# 9237    0
# 9238    5
# 9239    0
# Length: 9240, dtype: int64

# %%
100 * (lead.isnull().sum() / len(lead.index)) , len(lead.index)
# Out:
# (Prospect ID                                       0.000000
#  Lead Number                                       0.000000
#  Lead Origin                                       0.000000
#  Lead Source                                       0.389610
#  Do Not Email                                      0.000000
#  Do Not Call                                       0.000000
#  Converted                                         0.000000
#  TotalVisits                                       1.482684
#  Total Time Spent on Website                       0.000000
#  Page Views Per Visit                              1.482684
#  Last Activity                                     1.114719
#  Country                                          26.634199
#  Specialization                                   15.562771
#  How did you hear about X Education               23.885281
#  What is your current occupation                  29.112554
#  What matters most to you in choosing a course    29.318182
# ...

# %%
lead_df = lead[lead.isnull().sum(axis = 1) <= 5]
100 * (lead_df.isnull().sum() / len(lead.index))
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.183983
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       0.757576
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              0.757576
# Last Activity                                     0.573593
# Country                                          13.766234
# Specialization                                    0.000000
# How did you hear about X Education                0.281385
# What is your current occupation                   3.235931
# What matters most to you in choosing a course     3.235931
# ...

# %%
len(lead.index)
# Out:
# 9240

# %%
var1 = lead[['Asymmetrique Activity Index','Asymmetrique Profile Index','Asymmetrique Activity Score','Asymmetrique Profile Score']]
lead_df = lead.drop(var1 , axis = 1)
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
len(lead_df.index)
# Out:
# 9240

# %%
lead_df.drop('Lead Quality' , axis = 1, inplace = True)

# %%
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
lead_df.drop('Tags' , axis = 1, inplace = True)

# %%
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
lead_df.drop('Country', axis = 1, inplace = True)
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# Search                                            0.000000
# ...

# %%
var2 = lead[['What is your current occupation', 'What matters most to you in choosing a course']]
lead_df.drop(var2, axis = 1, inplace = True)
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                  0.000000
# Lead Number                                  0.000000
# Lead Origin                                  0.000000
# Lead Source                                  0.389610
# Do Not Email                                 0.000000
# Do Not Call                                  0.000000
# Converted                                    0.000000
# TotalVisits                                  1.482684
# Total Time Spent on Website                  0.000000
# Page Views Per Visit                         1.482684
# Last Activity                                1.114719
# Specialization                              15.562771
# How did you hear about X Education          23.885281
# Search                                       0.000000
# Magazine                                     0.000000
# Newspaper Article                            0.000000
# X Education Forums                           0.000000
# ...

# %%
lead_df.loc[pd.isnull(lead_df['Lead Profile']), 'Lead Profile'] = 'Unassigned'
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                  0.000000
# Lead Number                                  0.000000
# Lead Origin                                  0.000000
# Lead Source                                  0.389610
# Do Not Email                                 0.000000
# Do Not Call                                  0.000000
# Converted                                    0.000000
# TotalVisits                                  1.482684
# Total Time Spent on Website                  0.000000
# Page Views Per Visit                         1.482684
# Last Activity                                1.114719
# Specialization                              15.562771
# How did you hear about X Education          23.885281
# Search                                       0.000000
# Magazine                                     0.000000
# Newspaper Article                            0.000000
# X Education Forums                           0.000000
# ...

# %%
lead_df = lead_df.dropna()
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                 0.0
# Lead Number                                 0.0
# Lead Origin                                 0.0
# Lead Source                                 0.0
# Do Not Email                                0.0
# Do Not Call                                 0.0
# Converted                                   0.0
# TotalVisits                                 0.0
# Total Time Spent on Website                 0.0
# Page Views Per Visit                        0.0
# Last Activity                               0.0
# Specialization                              0.0
# How did you hear about X Education          0.0
# Search                                      0.0
# Magazine                                    0.0
# Newspaper Article                           0.0
# X Education Forums                          0.0
# Newspaper                                   0.0
# Digital Advertisement                       0.0
# Through Recommendations                     0.0
# ...

# %%
len(lead_df.index) , lead_df.shape , len(lead.index)
# Out:
# (6871, (6871, 28), 9240)

# %%
lead_df.drop(columns= 'Magazine' , inplace = True)

# %%
lead_df.drop(columns= 'Receive More Updates About Our Courses' , inplace = True)
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                                 0.0
# Lead Number                                 0.0
# Lead Origin                                 0.0
# Lead Source                                 0.0
# Do Not Email                                0.0
# Do Not Call                                 0.0
# Converted                                   0.0
# TotalVisits                                 0.0
# Total Time Spent on Website                 0.0
# Page Views Per Visit                        0.0
# Last Activity                               0.0
# Specialization                              0.0
# How did you hear about X Education          0.0
# Search                                      0.0
# Newspaper Article                           0.0
# X Education Forums                          0.0
# Newspaper                                   0.0
# Digital Advertisement                       0.0
# Through Recommendations                     0.0
# Update me on Supply Chain Content           0.0
# ...

# %%
lead_df.drop(columns= ['Update me on Supply Chain Content','Get updates on DM Content','I agree to pay the amount through cheque'] , inplace = True)
len(lead_df.index) , lead_df.shape , len(lead.index)
# Out:
# (6871, (6871, 23), 9240)

# %%
100 * (lead_df.isnull().sum()/len(lead_df.index))
# Out:
# Prospect ID                               0.0
# Lead Number                               0.0
# Lead Origin                               0.0
# Lead Source                               0.0
# Do Not Email                              0.0
# Do Not Call                               0.0
# Converted                                 0.0
# TotalVisits                               0.0
# Total Time Spent on Website               0.0
# Page Views Per Visit                      0.0
# Last Activity                             0.0
# Specialization                            0.0
# How did you hear about X Education        0.0
# Search                                    0.0
# Newspaper Article                         0.0
# X Education Forums                        0.0
# Newspaper                                 0.0
# Digital Advertisement                     0.0
# Through Recommendations                   0.0
# Lead Profile                              0.0
# ...

# %%
lead_df['Do Not Email'] = lead_df['Do Not Email'].map({'Yes' : 1 , 'No':0})

# %%
lead_df['Do Not Call'] = lead_df['Do Not Call'].map({'Yes' : 1 , 'No':0})
lead_df['Search'] = lead_df['Search'].map({'Yes':1 , 'No':0})
lead_df['Newspaper Article'] = lead_df['Newspaper Article'].map({'Yes':1 , 'No':0})
lead_df['X Education Forums']=lead_df['X Education Forums'].map({'Yes':1 , 'No':0})
lead_df['Newspaper']=   lead_df['Newspaper'].map({'Yes':1 , 'No':0})
lead_df['Digital Advertisement']=   lead_df['Digital Advertisement'].map({'Yes':1 , 'No':0})
lead_df['Through Recommendations'] =    lead_df['Through Recommendations'].map({'Yes':1 , 'No':0})
lead_df['A free copy of Mastering The Interview'] =   lead_df['A free copy of Mastering The Interview'].map({'Yes':1 , 'No':0})

# %%
lead_df['Do Not Email'].value_counts()
# Out:
# 0    6409
# 1     462
# Name: Do Not Email, dtype: int64

# %%
lead_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6871 entries, 0 to 9239
# Data columns (total 23 columns):
# Prospect ID                               6871 non-null object
# Lead Number                               6871 non-null int64
# Lead Origin                               6871 non-null object
# Lead Source                               6871 non-null object
# Do Not Email                              6871 non-null int64
# Do Not Call                               6871 non-null int64
# Converted                                 6871 non-null int64
# TotalVisits                               6871 non-null float64
# Total Time Spent on Website               6871 non-null int64
# Page Views Per Visit                      6871 non-null float64
# Last Activity                             6871 non-null object
# Specialization                            6871 non-null object
# How did you hear about X Education        6871 non-null object
# ...

# %%
origin = pd.get_dummies(lead_df['Lead Origin'], prefix = 'lead origin' , drop_first = True)
lead_df =pd.concat([lead_df,origin], axis =1)

survey = pd.get_dummies(lead_df['Lead Source'], prefix = 'lead source' , drop_first = True)
lead_df =pd.concat([lead_df,survey], axis =1)

activity = pd.get_dummies(lead_df['Last Notable Activity'],prefix = 'last activity' , drop_first = True)
lead_df = pd.concat([lead_df , activity] , axis = 1)

activity_1 = pd.get_dummies(lead_df['Last Activity'],prefix = 'activity_1' , drop_first = True)
lead_df = pd.concat([lead_df , activity_1] , axis = 1)

# %%
lead_df.shape
# Out:
# (6871, 72)

# %%
#Creating dummy variables for the remaining categorical variables and dropping the first again
sp=pd.get_dummies(lead_df['Specialization'],prefix='specialization' , drop_first = True)
leads_df=pd.concat([lead_df,sp],axis=1)

he=pd.get_dummies(lead_df['How did you hear about X Education'],prefix='How heard', drop_first = True)
leads_df=pd.concat([lead_df,he],axis=1)

lp=pd.get_dummies(lead_df['Lead Profile'],prefix='Lead Profile',drop_first = True)
leads_df=pd.concat([lead_df,lp],axis=1)

city=pd.get_dummies(lead_df['City'],prefix='City', drop_first = True)
leads_df=pd.concat([lead_df,city],axis=1)

# %%
list3 = ['Lead Origin','Lead Source','Last Notable Activity','Specialization','How did you hear about X Education','Lead Profile','City', 'Last Activity']
lead_df = lead_df.drop(list3 , axis = 1)

# %%
num_list = ['TotalVisits','Total Time Spent on Website' , 'Page Views Per Visit']
lead_df[num_list].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
lead_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6871 entries, 0 to 9239
# Data columns (total 64 columns):
# Prospect ID                                   6871 non-null object
# Lead Number                                   6871 non-null int64
# Do Not Email                                  6871 non-null int64
# Do Not Call                                   6871 non-null int64
# Converted                                     6871 non-null int64
# TotalVisits                                   6871 non-null float64
# Total Time Spent on Website                   6871 non-null int64
# Page Views Per Visit                          6871 non-null float64
# Search                                        6871 non-null int64
# Newspaper Article                             6871 non-null int64
# X Education Forums                            6871 non-null int64
# Newspaper                                     6871 non-null int64
# ...

# %%
Conversion_Rate =  ( float(lead_df.Converted.sum()) / len(lead_df.Converted.index)) * 100
Conversion_Rate
# Out:
# 45.8739630330374

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()



q1 = lead_df['TotalVisits'].quantile(0.25)
q3 =  lead_df['TotalVisits'].quantile(0.75)
iqr1 = q3 - q1
lead_df = lead_df[(lead_df['TotalVisits']>=q1-1.5*iqr1) & (lead_df['TotalVisits']<=q3+1.5*iqr1)]

# %%
len(lead_df.index)
# Out:
# 6490

# %%
x=lead_df.drop(['Prospect ID','Lead Number','Converted'],axis=1)
y=lead_df['Converted']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , train_size = 0.7 , test_size = 0.3 , random_state = 100)

# %%
x_train[num_list] = scaler.fit_transform(x_train[num_list])
# Out:
# C:\Users\Dell\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x_test[num_list] = scaler.fit_transform(x_test[num_list])
# Out:
# C:\Users\Dell\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x_test.head()
# Out:
#       Do Not Email  Do Not Call  TotalVisits  Total Time Spent on Website  \
# 7318             1            0    -0.450167                    -0.915848
# 898              0            0    -0.450167                    -0.649610
# 282              0            0     2.150651                    -0.867278
# 3795             0            0    -0.016698                    -0.368980
# 3523             0            0    -0.450167                    -0.710773
#
#       Page Views Per Visit  Search  Newspaper Article  X Education Forums  \
# 7318             -0.223309       0                  0                   0
# 898              -0.223309       0                  0                   0
# 282               2.972178       0                  0                   0
# 3795              0.309272       0                  0                   0
# 3523             -0.755891       0                  0                   0
#
# ...

# %%
#logistic regression model
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import statsmodels.api as sm
LR1 = sm.GLM(y_train , (sm.add_constant(x_train)), family = sm.families.Binomial())
LR1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4488
# Model Family:                Binomial   Df Model:                           54
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                    nan
# Date:                Sun, 03 Mar 2019   Deviance:                          nan
# Time:                        20:44:24   Pearson chi2:                 6.26e+18
# No. Iterations:                   100   Covariance Type:             nonrobust
# ...
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# ...

# %%
# PCA adn Incremental PCA

from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA

pca = PCA(svd_solver = 'randomized' , random_state = 50)
pca.fit(x_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=50,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-4.18168476e-03,  2.32244680e-04,  6.10946708e-01, ...,
#          4.05438138e-04, -1.91966037e-04,  5.60524538e-05],
#        [-6.78841731e-03,  1.74738473e-04, -2.69703195e-01, ...,
#         -1.80539358e-03, -2.89119908e-04, -2.74344367e-04],
#        [ 4.68496247e-02, -2.40520994e-04,  5.27803769e-02, ...,
#          1.48365326e-03,  1.11615915e-04,  1.08530006e-04],
#        ...,
#        [ 0.00000000e+00,  2.38189053e-16,  8.01035162e-18, ...,
#          4.16333634e-17,  7.18826040e-17, -1.90602742e-16],
#        [ 0.00000000e+00,  1.63226637e-16, -1.43212487e-16, ...,
#          1.66533454e-16, -3.38271078e-17, -2.14238349e-16],
#        [-0.00000000e+00,  3.29597460e-16, -2.92366749e-17, ...,
#         -8.32667268e-17,  9.23740251e-17, -1.32489505e-16]])

# %%
pca.explained_variance_ratio_
# Out:
# array([3.83932132e-01, 1.37314811e-01, 1.09968748e-01, 8.05245132e-02,
#        6.48339234e-02, 3.82991224e-02, 3.41519476e-02, 2.48886199e-02,
#        1.81803598e-02, 1.60256197e-02, 1.35491358e-02, 1.17600072e-02,
#        1.03197809e-02, 9.94124272e-03, 8.21797428e-03, 6.45145964e-03,
#        5.11360245e-03, 4.22676607e-03, 3.18658625e-03, 2.77606911e-03,
#        2.72521790e-03, 2.34030971e-03, 2.13814033e-03, 1.75706683e-03,
#        1.60809999e-03, 1.47777980e-03, 9.99339627e-04, 8.04154910e-04,
#        5.92374194e-04, 4.20924013e-04, 1.51263155e-04, 1.33176263e-04,
#        1.21403701e-04, 1.19866265e-04, 9.73011623e-05, 7.94376966e-05,
#        7.59015727e-05, 7.57942472e-05, 7.56252260e-05, 7.50004835e-05,
#        6.79980152e-05, 5.49098572e-05, 4.22458108e-05, 4.10237584e-05,
#        3.80781344e-05, 3.79656903e-05, 3.78773816e-05, 3.78521218e-05,
#        3.75967912e-05, 3.74740443e-05, 1.93274643e-05, 1.07683253e-05,
# ...

# %%
colnames = list(x_train.columns)
df_pcs =pd.DataFrame({'PC1': pca.components_[0] , 'PC2' : pca.components_[1] , 'Features' :colnames})
df_pcs.head()
# Out:
#                       Features       PC1       PC2
# 0                 Do Not Email -0.004182 -0.006788
# 1                  Do Not Call  0.000232  0.000175
# 2                  TotalVisits  0.610947 -0.269703
# 3  Total Time Spent on Website  0.398547  0.879341
# 4         Page Views Per Visit  0.608142 -0.290186

# %%
plt.scatter(df_pcs.PC1 , df_pcs.PC2)
plt.xlabel('PC1')
plt.ylabel('PC2')

for i , txt in enumerate(df_pcs.Features):
    plt.annotate(txt, (df_pcs.PC1[i],df_pcs.PC2[i]))
plt.show()

# %%
# Screeplot

fig = plt.figure(figsize=(6,4))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('components')
plt.ylabel('variance')
plt.show()

# about 90% variables can be explained by 30 variables

# %%
# Incremental PCA
pca_final = IncrementalPCA(n_components = 33)

# %%
df_train_pca = pca_final.fit_transform(x_train)
df_train_pca = pd.DataFrame(df_train_pca)
df_train_pca.shape
# Out:
# (4543, 33)

# %%
# correlation plot

corrmat = np.corrcoef(df_train_pca.transpose())
plt.figure(figsize=(23,20))
sns.heatmap(corrmat , annot = True)
plt.show()

# %%
# Print minimum and maximum correlation values

corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
corrmat_nodiag.max() , corrmat_nodiag.min()
# Out:
# (0.1564981970757822, -0.007336432828043762)

# %%
# Test data

df_test_pca = pca_final.transform(x_test)
df_test_pca.shape  # array need to be converted to DF
# Out:
# (1947L, 33L)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logreg = LogisticRegression()
model = logreg.fit(df_train_pca , y_train)

# %%
model_pred = model.predict_proba(df_test_pca)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, model_pred)) , model_pred
# Out:
# ('0.86',
#  array([0.12567075, 0.07649757, 0.02377838, ..., 0.15197806, 0.01382942,
#         0.90753483]))

# %%
model_pred = pd.DataFrame(model_pred)
pd.DataFrame(y_test).sort_values(by ='Converted' , ascending = False)
# Out:
#       Converted
# 2962          1
# 7840          1
# 3211          1
# 4008          1
# 9158          1
# 1597          1
# 6977          1
# 454           1
# 2946          1
# 7193          1
# 3893          1
# 3360          1
# 3265          1
# 4599          1
# 3147          1
# 1539          1
# 370           1
# 3163          1
# 5353          1
# 3907          1
# 5167          1
# 8038          1
# 1167          1
# 5931          1
# 4973          1
# 8790          1
# 3210          1
# 533           1
# 4753          1
# 4642          1
# ...         ...
# 5989          0
# 4711          0
# 2366          0
# 451           0
# 7101          0
# 654           0
# 1036          0
# 1782          0
# 2065          0
# 5429          0
# 1863          0
# 4814          0
# 2616          0
# 1133          0
# 8882          0
# 4988          0
# 9222          0
# 7122          0
# 2905          0
# 1939          0
# 8636          0
# 4294          0
# 2800          0
# ...

# %% [markdown]
# # model accuracy 0.86 using PCA, we have reduced the dimentionality of the dataset. This can be considered as valid model. Still I will create a model using RFE

# %%
#RFE

import statsmodels.api as sm
from sklearn.feature_selection import RFE

rfe = RFE(logreg , 20)
rfe.fit(x,y)
# Out:
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#   n_features_to_select=20, step=1, verbose=0)

# %%
col = x.columns[rfe.support_]
xtrain = x_train[col]
xtrain_sm = sm.add_constant(xtrain)

# %%
logm=sm.GLM(y_train,xtrain_sm,family=sm.families.Binomial()).fit()
logm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4522
# Model Family:                Binomial   Df Model:                           20
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2559.1
# Date:                Sun, 03 Mar 2019   Deviance:                       5118.1
# Time:                        20:44:36   Pearson chi2:                 4.65e+03
# No. Iterations:                    20   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
# Dropping variable with highest p value
xtrain=xtrain.drop('Do Not Call',axis=1)
lm1=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4523
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2560.1
# Date:                Sun, 03 Mar 2019   Deviance:                       5120.1
# Time:                        20:44:36   Pearson chi2:                 4.65e+03
# No. Iterations:                    20   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
# Calculate VIF to check for any multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = xtrain.columns
vif['VIF'] = [variance_inflation_factor(xtrain.values, i) for i in range(xtrain.shape[1])]
vif['VIF'] =vif['VIF']
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features        VIF
# 2                 lead origin_Lead Add Form  48.513182
# 3                     lead source_Reference  38.450510
# 4              lead source_Welingak Website  11.022631
# 7                    last activity_Modified   1.917468
# 10                 activity_1_Email Bounced   1.717155
# 0                              Do Not Email   1.675136
# 17                   activity_1_Unreachable   1.620210
# 8                 last activity_Unreachable   1.574977
# 9              activity_1_Converted to Lead   1.289429
# 15       activity_1_Olark Chat Conversation   1.259688
# 16       activity_1_Page Visited on Website   1.110355
# 13     activity_1_Form Submitted on Website   1.092610
# 6                last activity_Email Opened   1.023258
# 11             activity_1_Email Marked Spam   1.005621
# 5          last activity_Email Link Clicked   1.002963
# 18  activity_1_View in browser link Clicked   1.002680
# ...

# %%
xtrain=xtrain.drop('lead origin_Lead Add Form',axis=1)
lm2=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4524
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2561.8
# Date:                Sun, 03 Mar 2019   Deviance:                       5123.6
# Time:                        20:44:37   Pearson chi2:                 4.65e+03
# No. Iterations:                    20   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = xtrain.columns
vif['VIF'] = [variance_inflation_factor(xtrain.values, i) for i in range(xtrain.shape[1])]
vif['VIF'] =vif['VIF']
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features       VIF
# 6                    last activity_Modified  1.917141
# 9                  activity_1_Email Bounced  1.717155
# 0                              Do Not Email  1.675100
# 16                   activity_1_Unreachable  1.620202
# 7                 last activity_Unreachable  1.574973
# 8              activity_1_Converted to Lead  1.289380
# 14       activity_1_Olark Chat Conversation  1.259647
# 15       activity_1_Page Visited on Website  1.108779
# 12     activity_1_Form Submitted on Website  1.092595
# 2                     lead source_Reference  1.043729
# 5                last activity_Email Opened  1.022424
# 3              lead source_Welingak Website  1.012618
# 10             activity_1_Email Marked Spam  1.005621
# 4          last activity_Email Link Clicked  1.002963
# 17  activity_1_View in browser link Clicked  1.002679
# 13      activity_1_Had a Phone Conversation  1.002612
# ...

# %%
xtrain=xtrain.drop('Through Recommendations',axis=1)
lm3=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm3.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4525
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2562.2
# Date:                Sun, 03 Mar 2019   Deviance:                       5124.4
# Time:                        20:44:37   Pearson chi2:                 4.65e+03
# No. Iterations:                    20   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
xtrain=xtrain.drop('activity_1_Email Marked Spam',axis=1)
lm4=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm4.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4526
# Model Family:                Binomial   Df Model:                           16
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2563.4
# Date:                Sun, 03 Mar 2019   Deviance:                       5126.7
# Time:                        20:44:37   Pearson chi2:                 4.65e+03
# No. Iterations:                    20   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = xtrain.columns
vif['VIF'] = [variance_inflation_factor(xtrain.values, i) for i in range(xtrain.shape[1])]
vif['VIF'] =vif['VIF']
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                                    Features       VIF
# 5                    last activity_Modified  1.916918
# 8                  activity_1_Email Bounced  1.713651
# 0                              Do Not Email  1.665723
# 14                   activity_1_Unreachable  1.620152
# 6                 last activity_Unreachable  1.574955
# 7              activity_1_Converted to Lead  1.289346
# 12       activity_1_Olark Chat Conversation  1.259614
# 13       activity_1_Page Visited on Website  1.107225
# 10     activity_1_Form Submitted on Website  1.092584
# 1                     lead source_Reference  1.043710
# 4                last activity_Email Opened  1.021476
# 2              lead source_Welingak Website  1.012598
# 3          last activity_Email Link Clicked  1.002963
# 15  activity_1_View in browser link Clicked  1.002679
# 11      activity_1_Had a Phone Conversation  1.002609
# 9                 activity_1_Email Received  1.000000

# %%
xtrain=xtrain.drop('activity_1_Email Received',axis=1)
lm5=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm5.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4527
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2563.8
# Date:                Sun, 03 Mar 2019   Deviance:                       5127.5
# Time:                        20:44:38   Pearson chi2:                 4.66e+03
# No. Iterations:                    19   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
xtrain=xtrain.drop('activity_1_Had a Phone Conversation',axis=1)
lm6=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm6.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4528
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2565.7
# Date:                Sun, 03 Mar 2019   Deviance:                       5131.4
# Time:                        20:44:38   Pearson chi2:                 4.65e+03
# No. Iterations:                    19   Covariance Type:             nonrobust
# ...
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# ...

# %%
xtrain=xtrain.drop('activity_1_View in browser link Clicked',axis=1)
lm7=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm7.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4529
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2566.6
# Date:                Sun, 03 Mar 2019   Deviance:                       5133.2
# Time:                        20:44:38   Pearson chi2:                 4.66e+03
# No. Iterations:                     7   Covariance Type:             nonrobust
# ...
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
xtrain=xtrain.drop('activity_1_Form Submitted on Website',axis=1)
lm8=sm.GLM(y_train,(sm.add_constant(xtrain)),family=sm.families.Binomial())
lm8.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 4543
# Model:                            GLM   Df Residuals:                     4530
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2568.8
# Date:                Sun, 03 Mar 2019   Deviance:                       5137.6
# Time:                        20:44:39   Pearson chi2:                 4.66e+03
# No. Iterations:                     7   Covariance Type:             nonrobust
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = xtrain.columns
vif['VIF'] = [variance_inflation_factor(xtrain.values, i) for i in range(xtrain.shape[1])]
vif['VIF'] =vif['VIF']
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                               Features       VIF
# 5               last activity_Modified  1.747790
# 8             activity_1_Email Bounced  1.703907
# 0                         Do Not Email  1.664911
# 11              activity_1_Unreachable  1.614080
# 6            last activity_Unreachable  1.572695
# 7         activity_1_Converted to Lead  1.263817
# 9   activity_1_Olark Chat Conversation  1.236610
# 10  activity_1_Page Visited on Website  1.098258
# 1                lead source_Reference  1.042767
# 4           last activity_Email Opened  1.021450
# 2         lead source_Welingak Website  1.012251
# 3     last activity_Email Link Clicked  1.002960

# %%
xtrain.head()
# Out:
#       Do Not Email  lead source_Reference  lead source_Welingak Website  \
# 4112             0                      0                             0
# 7374             0                      0                             0
# 1874             0                      0                             0
# 3289             0                      1                             0
# 9058             0                      0                             0
#
#       last activity_Email Link Clicked  last activity_Email Opened  \
# 4112                                 0                           0
# 7374                                 0                           0
# 1874                                 0                           1
# 3289                                 1                           0
# 9058                                 0                           1
#
#       last activity_Modified  last activity_Unreachable  \
# 4112                       0                          0
# ...

# %% [markdown]
# # Now the VIF for train dataset there is no multi-collinearity in the model lm8 and that can be considered as the model for coefficients of variables
